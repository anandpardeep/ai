# %%
# un-comment any of the following:
# !pip install pymupdf
# !pip install matplotlib
# !pip install pandas
# !pip install numpy
# !pip install pymupdf4llm

# %%
import fitz

# %%
file="/Users/anandpardeep/AI/CrowdStrikeGlobalThreatReport2025.pdf"
doc = fitz.open(file)
page = doc[0]

# %%
page
# Out:
# page 0 of /Users/anandpardeep/AI/CrowdStrikeGlobalThreatReport2025.pdf

# %%
for page_num, page in enumerate(doc, start=1):
    table_finder = page.find_tables()
    tables = table_finder.tables

    print(f"Page {page_num}: Found {len(tables)} table(s)")
    
    for i, table in enumerate(tables, start=1):
        print(f"\nTable {i} (Markdown):")
        print(table.to_pandas())
# Out:
# Page 1: Found 0 table(s)
# Page 2: Found 0 table(s)
# Page 3: Found 0 table(s)
# Page 4: Found 0 table(s)
# Page 5: Found 0 table(s)
# Page 6: Found 0 table(s)
# Page 7: Found 0 table(s)
# Page 8: Found 0 table(s)
# Page 9: Found 0 table(s)
# Page 10: Found 0 table(s)
# Page 11: Found 0 table(s)
# Page 12: Found 0 table(s)
# Page 13: Found 0 table(s)
# Page 14: Found 0 table(s)
# Page 15: Found 0 table(s)
# Page 16: Found 1 table(s)
#
# Table 1 (Markdown):
# Empty DataFrame
# Columns: [64
# 55
# 33
# 20
# 10 9 11 10
# 5
# 2 3, Col1, Col2]
# Index: []
# Page 17: Found 1 table(s)
#
# Table 1 (Markdown):
#   Victim downloads RMM tool, providing these adversaries with access  \
# 0                           Quick Access, TeamViewer
#
#                                                 Col1
# 0  SoftEther VPN, Ammyy Admin,\nDWAgent, HopToDes...
# Page 18: Found 0 table(s)
# Page 19: Found 0 table(s)
# Page 20: Found 0 table(s)
# Page 21: Found 1 table(s)
#
# Table 1 (Markdown):
#   AD\nFA\nIn 20\nbroa\ninsid\ncybe\nBeav\nThe\nusing\nsoftw\nWest\nresp\nthe y  \
# 0                                               None
#
#                                                 Col1
# 0  VERSARY SPOTLIGHT:\nMOUS CHOLLIMA\n24, FAMOUS ...
# Page 22: Found 0 table(s)
# Page 23: Found 0 table(s)
# Page 24: Found 0 table(s)
# Page 25: Found 0 table(s)
# Page 26: Found 0 table(s)
# Page 27: Found 0 table(s)
# Page 28: Found 0 table(s)
# Page 29: Found 0 table(s)
# Page 30: Found 0 table(s)
# Page 31: Found 0 table(s)
# Page 32: Found 0 table(s)
# Page 33: Found 1 table(s)
#
# Table 1 (Markdown):
#   EXECUTION\nCommand line\nfrom comprom\nVMs with cac\ncredential\nCLOUD COMMAND\nLINE TOOLS\nTHREAT\nACTOR\nThreat actor accesses cloud infrastructure  \
# 0                                               None
# 1                                               None
# 2                                               None
#
#    tools\nised\nhed\ns  \
# 0
# 1  CLOUD CONTROL PLANE
# 2                 None
#
#   VM management tools\nVIRTUAL MACHINE-BASED\nEXECUTION\nSearch for unsecured credentials on compromised infrastructure
# 0                                               None
# 1                                               None
# 2
# Page 34: Found 0 table(s)
# Page 35: Found 0 table(s)
# Page 36: Found 2 table(s)
#
# Table 1 (Markdown):
#   JUNE 11, 2024\nMicrosoft discloses five related vulnerabilities\nJULY 9, 2024\nMicrosoft discloses four related vulnerabilities\nAUGUST 13, 2024\nMicrosoft discloses four related vulnerabilities\nSEPTEMBER 10, 2024\nMicrosoft discloses CVE-2024-38245\nOCTOBER 8, 2024\nMicrosoft discloses CVE-2024-43554\nOCTOBER 13, 2024\nMARCH 23, 2023 Industry researcher releases POC exploit for\nSynacktiv exploits zero-day vulnerability CVE-2024-35250 based on DEVCORE's research\n(CVE-2023-29360) during Pwn2Own Vancouver\nOCTOBER 15, 2024\nSEPTEMBER 12, 2023\nCrowdStrike Intelligence observes\nMicrosoft discloses CVE-2023-36802\nfirst CVE-2024-35250 sample in the wild\nMARCH 20, 2024 NOVEMBER 21, 2024\nDEVCORE exploits zero-day Unknown actor attempts to execute\nvulnerability (CVE-2024-35250) during CVE-2024-35250 exploit\nPwn2Own Vancouver  \
# 0
#
#   Col1 Col2 Col3 Col4 Col5 Col6 Col7 Col8 Col9 Col10 Col11 Col12 Col13
# 0
#
# Table 2 (Markdown):
#   MARCH 23, 2023\nSynacktiv exploits zero-day\n(CVE-2023-29360) during Pwn  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
#
#                                     Col1                          Col2  \
# 0                                   None                          None
# 1  SEPTEMBER 12, 202\nMicrosoft disclose                          None
# 2                                   None                          None
# 3                                   None                          None
# 4                                   None  MARCH\nDEVCOR\nvulner\nPwn2O
# 5                                   None                          None
#
#                      vulnera\n2Own V                bility\nancouver  \
# 0
# 1                         3\ns CVE-2                        023-3680
# 2                               None                            None
# 3
# 4  20, 20\nE explo\nability\nwn Vanc  24\nits zero-\n(CVE-202\nouver
# 5
#
#            Col5     Col6  Col7  Col8  Col9
# 0          None     None  None  None  None
# 1             2     None  None  None  None
# 2          None     None  None        None
# 3          None     None  None  None  None
# 4  day\n4-35250  ) durin     g
# 5                                     None
# Page 37: Found 0 table(s)
# Page 38: Found 0 table(s)
# Page 39: Found 1 table(s)
#
# Table 1 (Markdown):
#    Col0 JUL 10\nPublic\nDisclo  sure  Col3  \
# 0  None                         None  None
# 1  None                   None  None  None
# 2  None                   None  None  None
# 3  None                   None  None  None
# 4  None                   None  None  None
# 5  None                   None  None  None
# 6  None                   None  None  None
#
#   OCT 9 OCT 10\nTechnical Blog First Observed\nFirst POC Exploitation  \
# 0
# 1                          OCT 9\nPublic\nDisclosure
# 2
# 3  OCT 9\nPublic Disclosure\nTechnical Blog\nFirs...
# 4
# 5           OCT 9\nPublic Disclosure\nTechnical Blog
# 6
#
#                                                 Col5  \
# 0                                               None
# 1  O FiC rT s t1 0 P OC O TeC cT h n11 i cal Blog...
# 2
# 3
# 4
# 5
# 6
#
#                                    Col6  Col7  \
# 0                                  None  None
# 1                                  None  None
# 2                                        None
# 3  OCT 11\nFirst Observed\nExploitation  None
# 4                                        None
# 5
# 6
#
#                                              Col8  \
# 0                                            None
# 1                                            None
# 2                                            None
# 3                                            None
# 4                                            None
# 5  OCT 14\nFirst Observed\nExploitation\nAttempts
# 6
#
#                                 Col9
# 0                               None
# 1                               None
# 2                               None
# 3  OCT 18\nFirst ORB01\nExploitation
# 4
# 5                               None
# 6                               None
# Page 40: Found 1 table(s)
#
# Table 1 (Markdown):
#   Col0 DOC\nS
# 0        None
# Page 41: Found 0 table(s)
# Page 42: Found 0 table(s)
# Page 43: Found 0 table(s)
# Page 44: Found 0 table(s)
# Page 45: Found 0 table(s)
# Page 46: Found 0 table(s)
# Page 47: Found 0 table(s)
# Page 48: Found 0 table(s)
# Page 49: Found 0 table(s)
# Page 50: Found 0 table(s)
# Page 51: Found 0 table(s)
# Page 52: Found 0 table(s)
# Page 53: Found 0 table(s)
